# %% [markdown]
# <a href="https://colab.research.google.com/github/moeenessa31-lgtm/Project/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os

# %%
# !git clone https://github.com/moeenessa31-lgtm/Project
# %cd Project

# %%
# !git add "/content/Fall2025_DS230_Final project.pdf"


# !git commit -m "Added Fall2025_DS230_Final project.pdf and Colab notebook"

# %%
# !git push -u origin main

# %%
# !git config --global user.email "moeanessa31@gmail.com"
# !git config --global user.name "HAMZA"
# !git config --global user.email "zaidazamy449@gmail.com"
# !git config --global user.name "ZAID"

# %%
# Load the orders data
print('--- Loading orders.csv ---')
orders_df = pd.read_csv('/content/orders.csv')
print(orders_df.head())
print('\n')
# Out:
# --- Loading orders.csv ---
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Load the products data
print('--- Loading products.csv ---')
products_df = pd.read_csv('/content/products.csv')
print(products_df.head())
# Out:
# --- Loading products.csv ---
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
# Load the aisles data
print('--- Loading aisles.csv ---')
aisles_df = pd.read_csv('/content/aisles.csv')
print(aisles_df.head())
# Out:
# --- Loading aisles.csv ---
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# Load the departments data
print('--- Loading departments.csv ---')
departments_df = pd.read_csv('/content/departments.csv')
print(departments_df.head())
# Out:
# --- Loading departments.csv ---
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# Load prior order products data
print('--- Loading order_products__prior.csv ---')
order_products_prior_df = pd.read_csv('/content/order_products__prior.csv')
print(order_products_prior_df.head())
# Out:
# --- Loading order_products__prior.csv ---
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                1.0        1.0
# 1         2       28985                2.0        1.0
# 2         2        9327                3.0        0.0
# 3         2       45918                4.0        1.0
# 4         2       30035                5.0        0.0

# %%
# Load training order products data
print('--- Loading order_products__train.csv ---')
order_products_train_df = pd.read_csv('/content/order_products__train.csv')
print(order_products_train_df.head())
# Out:
# --- Loading order_products__train.csv ---
#    order_id  product_id  add_to_cart_order  reordered
# 0         1     49302.0                1.0        1.0
# 1         1     11109.0                2.0        1.0
# 2         1     10246.0                3.0        0.0
# 3         1     49683.0                4.0        0.0
# 4         1     43633.0                5.0        1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

print("Push Your Kaggle Key:")
files.upload()
# Out:
# Push Your Kaggle Key:
#      <input type="file" id="files-0d8d3bce-98ce-4e13-9c01-09c8b120b0ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d8d3bce-98ce-4e13-9c01-09c8b120b0ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d psparks/instacart-market-basket-analysis
# Out:
# Dataset URL: https://www.kaggle.com/datasets/psparks/instacart-market-basket-analysis
# License(s): CC0-1.0
# ...
#  90% 178M/197M [00:00<00:00, 1.86GB/s]
# 100% 197M/197M [00:00<00:00, 1.53GB/s]

# %%
# !unzip -q instacart-market-basket-analysis.zip -d instacart_data

# %% [markdown]
# --------------------------------------------------------------------------------
#
#
# ---

# %%
print(os.listdir("instacart_data"))
# Out:
# ['order_products__train.csv', 'departments.csv', 'orders.csv', 'order_products__prior.csv', 'aisles.csv', 'products.csv']

# %%
part = 'instacart_data/'
